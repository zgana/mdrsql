# %% [markdown]
# # Filtering and Aggregation

# %% [markdown]
# In this chapter we introduce the following query syntax:
#
# * `WHERE` for filtering
# * `AS` and other aliasing syntax
#
# We will also introduce several boolean operators useful in expressions:
#
# * `AND`, `OR`, `NOT`
# * `=`, `<>`
# * `>`, `>=`, `<`, `<=`
#
# Finally, we will introduce several aggregate functions:
#
# * `AVG`, `SUM`
# * `MIN`, `MAX`
# * `COUNT`

# %%
#| echo: false

import pandas as pd
import pyhive.sqlalchemy_presto

# always show every column
pd.set_option('display.max_columns', None)
# suppress a SQLAlchemy warning
pyhive.sqlalchemy_presto.PrestoDialect.supports_statement_cache = False

# %load_ext sql
# %config SqlMagic.autocommit = False
# %config SqlMagic.displaycon = False
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False

# %sql presto://localhost:8080/

# %%
#| echo: false
#| output: false

## just a reminder
# %sql select * from listings limit 5
# Out:
#    listing_id                        listing_url       scrape_id  \
# 0        2595  https://www.airbnb.com/rooms/2595  20220603182654
# 1        5121  https://www.airbnb.com/rooms/5121  20220603182654
# 2        5136  https://www.airbnb.com/rooms/5136  20220603182654
# 3        5178  https://www.airbnb.com/rooms/5178  20220603182654
# 4        5203  https://www.airbnb.com/rooms/5203  20220603182654
#
#                 last_scraped                                      name  \
# 0  2022-06-04T00:00:00+00:00                     Skylit Midtown Castle
# 1  2022-06-04T00:00:00+00:00                           BlissArtsSpace!
# 2  2022-06-04T00:00:00+00:00  Spacious Brooklyn Duplex, Patio + Garden
# 3  2022-06-04T00:00:00+00:00          Large Furnished Room Near B'way
# 4  2022-06-03T00:00:00+00:00        Cozy Clean Guest Room - Family Apt
#
#                                          description  \
# 0  Beautiful, spacious skylit studio in the heart...
# 1  One room available for rent in a 2 bedroom apt...
# 2  We welcome you to stay in our lovely 2 br dupl...
# 3  Please don’t expect the luxury here just a bas...
# 4  Our best guests are seeking a safe, clean, spa...
#
#                                neighborhood_overview  \
# 0  Centrally located in the heart of Manhattan ju...
# 1
# 2
# 3    Theater district, many restaurants around here.
# 4  Our neighborhood is full of restaurants and ca...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/f0813a11-40b2...     2845
# 1  https://a0.muscache.com/pictures/2090980c-b68e...     7356
# 2  https://a0.muscache.com/pictures/miso/Hosting-...     7378
# 3  https://a0.muscache.com/pictures/12065/f070997...     8967
# 4  https://a0.muscache.com/pictures/103776/b37157...     7490
#
#              neighbourhood neighbourhood_cleansed  \
# 0  New York, United States                Midtown
# 1                              Bedford-Stuyvesant
# 2                                     Sunset Park
# 3  New York, United States                Midtown
# 4  New York, United States        Upper West Side
#
#   neighbourhood_group_cleansed  latitude  longitude  \
# 0                    Manhattan  40.75356  -73.98559
# 1                     Brooklyn  40.68535  -73.95512
# 2                     Brooklyn  40.66265  -73.99454
# 3                    Manhattan  40.76457  -73.98317
# 4                    Manhattan  40.80380  -73.96751
#
#                  property_type        room_type  accommodates bathrooms  \
# 0           Entire rental unit  Entire home/apt             1       NaN
# 1  Private room in rental unit     Private room             2       NaN
# 2           Entire rental unit  Entire home/apt             4       NaN
# 3  Private room in rental unit     Private room             2       NaN
# 4  Private room in rental unit     Private room             1       NaN
#
#   bathrooms_text bedrooms  beds  \
# 0         1 bath      NaN   1.0
# 1                     1.0   1.0
# 2      1.5 baths      2.0   2.0
# 3         1 bath      1.0   1.0
# 4  1 shared bath      1.0   1.0
#
#                                            amenities  price  minimum_nights  \
# 0  ["Essentials", "Bathtub", "Extra pillows and b...  225.0              30
# 1  ["Heating", "Long term stays allowed", "Kitche...   60.0              30
# 2  ["Dryer", "Heating", "Hair dryer", "Carbon mon...  275.0              21
# 3  ["Conditioner", "Essentials", "Extra pillows a...   68.0               2
# 4  ["Carbon monoxide alarm", "Heating", "Essentia...   75.0               2
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0            1125                    30.0                    30.0
# 1             730                    30.0                    30.0
# 2            1125                    21.0                    21.0
# 3              14                     2.0                     2.0
# 4              14                     2.0                     2.0
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                  1125.0                  1125.0                    30.0
# 1                   730.0                   730.0                    30.0
# 2                  1125.0                  1125.0                    21.0
# 3                    14.0                    14.0                     2.0
# 4                    14.0                    14.0                     2.0
#
#    maximum_nights_avg_ntm calendar_updated  has_availability  availability_30  \
# 0                  1125.0              NaN              True                0
# 1                   730.0              NaN              True               30
# 2                  1125.0              NaN              True                3
# 3                    14.0              NaN              True                3
# 4                    14.0              NaN              True                0
#
#    availability_60  availability_90  availability_365  \
# 0                3               33               308
# 1               60               90               365
# 2                3                4               250
# 3                5                9               172
# 4                0                0                 0
#
#        calendar_last_scraped  number_of_reviews  number_of_reviews_ltm  \
# 0  2022-06-04T00:00:00+00:00                 48                      0
# 1  2022-06-04T00:00:00+00:00                 50                      0
# 2  2022-06-04T00:00:00+00:00                  2                      1
# 3  2022-06-04T00:00:00+00:00                536                     62
# 4  2022-06-03T00:00:00+00:00                118                      0
#
#    number_of_reviews_l30d               first_review  \
# 0                       0  2009-11-21T00:00:00+00:00
# 1                       0  2009-05-28T00:00:00+00:00
# 2                       0  2014-01-02T00:00:00+00:00
# 3                       2  2009-05-06T00:00:00+00:00
# 4                       0  2009-09-07T00:00:00+00:00
#
#                  last_review  review_scores_rating  review_scores_accuracy  \
# 0  2019-11-04T00:00:00+00:00                  4.70                    4.72
# 1  2019-12-02T00:00:00+00:00                  4.52                    4.22
# 2  2021-08-08T00:00:00+00:00                  5.00                    5.00
# 3  2022-05-09T00:00:00+00:00                  4.23                    4.24
# 4  2017-07-21T00:00:00+00:00                  4.91                    4.83
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.62                   4.76
# 1                       4.09                   4.91
# 2                       5.00                   5.00
# 3                       3.75                   4.66
# 4                       4.82                   4.97
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.79                    4.86                 4.41
# 1                         4.91                    4.47                 4.52
# 2                         5.00                    4.50                 5.00
# 3                         4.44                    4.87                 4.39
# 4                         4.95                    4.94                 4.92
#
#   license  instant_bookable  reviews_per_month access_date        country  \
# 0                     False               0.31  2022-06-03  united-states
# 1                     False               0.32  2022-06-03  united-states
# 2                     False               0.02  2022-06-03  united-states
# 3                     False               3.37  2022-06-03  united-states
# 4                     False               0.76  2022-06-03  united-states
#
#   state           city
# 0    ny  new-york-city
# 1    ny  new-york-city
# 2    ny  new-york-city
# 3    ny  new-york-city
# 4    ny  new-york-city

# %% [markdown]
# ## `where`

# %% [markdown]
# So far we have "filtered" return data only in the most trivial sense: restricting the number of rows using `limit`:

# %%
# %%sql
#
# select
#     listing_id,
#     price,
#     accommodates,
#     neighbourhood_cleansed,
#     city,
#     state,
#     country
# from listings
# limit 5
# Out:
#    listing_id  price  accommodates neighbourhood_cleansed           city  \
# 0        2595  225.0             1                Midtown  new-york-city
# 1        5121   60.0             2     Bedford-Stuyvesant  new-york-city
# 2        5136  275.0             4            Sunset Park  new-york-city
# 3        5178   68.0             2                Midtown  new-york-city
# 4        5203   75.0             1        Upper West Side  new-york-city
#
#   state        country
# 0    ny  united-states
# 1    ny  united-states
# 2    ny  united-states
# 3    ny  united-states
# 4    ny  united-states

# %% [markdown]
# We can restrict our attention to rows matching specific criteria using the `where` clause, as in:
#
# ```sql
# select
#     [column specification]
# from [source specification]
# where [filter condition]
# ```

# %% [markdown]
# `[filter condition]` is a boolean expression that will look familiar to coders with any level of experience.  However, SQL does have some quirks that will take some getting used to:
#
# * The equality comparison operator is `=`, **NOT** `==`
# * The inequality comparison operator is `<>`

# %% [markdown]
# Let's take a look at some examples.  Here is another arbitrary set of listings, but this time from Paris:

# %%
# %%sql
#
# select
#     listing_id,
#     price,
#     accommodates,
#     neighbourhood_cleansed,
#     city,
#     state,
#     country
# from listings
# where city = 'paris'
# limit 5
# Out:
#    listing_id  price  accommodates neighbourhood_cleansed   city  \
# 0    26660141   90.0             4        Buttes-Chaumont  paris
# 1    25177338   59.0             2        Buttes-Chaumont  paris
# 2    25218084  500.0            10    Batignolles-Monceau  paris
# 3    23135649   65.0             2                  Passy  paris
# 4    23259887   51.0             2                Reuilly  paris
#
#            state country
# 0  ile-de-france  france
# 1  ile-de-france  france
# 2  ile-de-france  france
# 3  ile-de-france  france
# 4  ile-de-france  france

# %% [markdown]
# Here are some listings that are not from New York City:

# %%
# %%sql
#
# select
#     listing_id,
#     price,
#     accommodates,
#     neighbourhood_cleansed,
#     city,
#     state,
#     country
# from listings
# where city <> 'new-york-city'
# limit 5
# Out:
#    listing_id  price  accommodates    neighbourhood_cleansed       city  \
# 0    23726706   88.0             2  IJburg - Zeeburgereiland  amsterdam
# 1    35815036  105.0             2                Noord-Oost  amsterdam
# 2    31553121  152.0             4                Noord-West  amsterdam
# 3    34745823   87.0             2     Gaasperdam - Driemond  amsterdam
# 4    44586947  160.0             4     Gaasperdam - Driemond  amsterdam
#
#            state          country
# 0  north-holland  the-netherlands
# 1  north-holland  the-netherlands
# 2  north-holland  the-netherlands
# 3  north-holland  the-netherlands
# 4  north-holland  the-netherlands

# %% [markdown]
# Here are some NYC listings that accommodate at least 4 guests:

# %%
# %%sql
#
# select
#     listing_id,
#     price,
#     accommodates,
#     neighbourhood_cleansed,
#     city,
#     state,
#     country
# from listings
# where
#     city = 'new-york-city'
#     and accommodates >= 4
# limit 5
# Out:
#    listing_id  price  accommodates neighbourhood_cleansed           city  \
# 0        5136  275.0             4            Sunset Park  new-york-city
# 1        7097  199.0             4            Fort Greene  new-york-city
# 2        7801  395.0             4           Williamsburg  new-york-city
# 3        8490  135.0             5     Bedford-Stuyvesant  new-york-city
# 4       12937  140.0             4       Long Island City  new-york-city
#
#   state        country
# 0    ny  united-states
# 1    ny  united-states
# 2    ny  united-states
# 3    ny  united-states
# 4    ny  united-states

# %% [markdown]
# Above we introduced the boolean `and`.  Here is an extremely contrived, but equivalent, example that introduces both `or` and `not`:

# %%
# %%sql
#
# select
#     listing_id,
#     price,
#     accommodates,
#     neighbourhood_cleansed,
#     city,
#     state,
#     country
# from listings
# where
#     city = 'new-york-city'
#     and (
#         accommodates = 4
#         or not (
#             accommodates < 5
#         )
#     )
# limit 5
# Out:
#    listing_id  price  accommodates neighbourhood_cleansed           city  \
# 0        5136  275.0             4            Sunset Park  new-york-city
# 1        7097  199.0             4            Fort Greene  new-york-city
# 2        7801  395.0             4           Williamsburg  new-york-city
# 3        8490  135.0             5     Bedford-Stuyvesant  new-york-city
# 4       12937  140.0             4       Long Island City  new-york-city
#
#   state        country
# 0    ny  united-states
# 1    ny  united-states
# 2    ny  united-states
# 3    ny  united-states
# 4    ny  united-states

# %% [markdown]
# ## `where` with `order by`

# %% [markdown]
# We saw in the previous chapter that we can learn about rows at the extremes by using `order by` and `limit`.  For example, we looked at hosts with the most listings.  Let's now find the Amsterdam-based host with the most listings:

# %%
# %%sql
#
# select
#     host_id,
#     name,
#     since,
#     city,
#     calculated_listings_count
# from hosts
# where city = 'amsterdam'
# order by
#     calculated_listings_count desc
# limit 5
# Out:
#      host_id             name                      since       city  \
# 0  203731852     SWEETS Hotel  2018-07-20T00:00:00+00:00  amsterdam
# 1   14574533  Hotel Not Hotel  2014-04-22T00:00:00+00:00  amsterdam
# 2  138369331            Peter  2017-07-03T00:00:00+00:00  amsterdam
# 3   67005410        Feliciano  2016-04-13T00:00:00+00:00  amsterdam
# 4  241644101       Wittenberg  2019-02-07T00:00:00+00:00  amsterdam
#
#    calculated_listings_count
# 0                         20
# 1                         20
# 2                         20
# 3                         17
# 4                         15

# %% [markdown]
# Returning to the listings table, let's find the cheapest option in NYC that accommodates at least 4 guests and tolerates stays as short as just 2 nights:

# %%
# %%sql
#
# select
#     listing_id,
#     price,
#     accommodates,
#     minimum_nights,
#     neighbourhood_cleansed,
#     city,
#     state,
#     country
# from listings
# where
#     city = 'new-york-city'
#     and accommodates >= 4
#     and minimum_nights <= 2
# order by
#     price
# limit 5
# Out:
#    listing_id  price  accommodates  minimum_nights neighbourhood_cleansed  \
# 0    42065543    0.0             4               1                Midtown
# 1    42065564    0.0             5               1     Financial District
# 2    42279171    0.0             6               1              Chinatown
# 3    41792753    0.0             6               1     Financial District
# 4    41740615    0.0             4               1                Midtown
#
#             city state        country
# 0  new-york-city    ny  united-states
# 1  new-york-city    ny  united-states
# 2  new-york-city    ny  united-states
# 3  new-york-city    ny  united-states
# 4  new-york-city    ny  united-states

# %% [markdown]
# That doesn't look right, does it?  These hosts are probably not inviting guests to stay for free, so let's spot check one of these and see if we can understand what's going on.
#
# Since we're working in Jupyter, we can extract a `listing_id` from the previous cell's output like so:

# %%
listing_id = _.listing_id.iloc[0]
listing_id
# Out:
# 42065543

# %% [markdown]
# Then we can pull all data for this listing:

# %%
# %%sql
#
# select *
# from listings
# where listing_id = {listing_id}
# Out:
#    listing_id                            listing_url       scrape_id  \
# 0    42065543  https://www.airbnb.com/rooms/42065543  20220603182654
#
#                 last_scraped                  name description  \
# 0  2022-06-03T00:00:00+00:00  Broadway Plaza Hotel
#
#   neighborhood_overview                                        picture_url  \
# 0                        https://a0.muscache.com/pictures/miso/Hosting-...
#
#      host_id neighbourhood neighbourhood_cleansed  \
# 0  307634016                              Midtown
#
#   neighbourhood_group_cleansed  latitude  longitude           property_type  \
# 0                    Manhattan  40.74444   -73.9892  Room in boutique hotel
#
#     room_type  accommodates bathrooms bathrooms_text bedrooms beds  \
# 0  Hotel room             4       NaN                     NaN  NaN
#
#                                            amenities  price  minimum_nights  \
# 0  ["Bathtub", "Geneva Guild toiletries", "Bed sh...    0.0               1
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0             365                     1.0                     1.0
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                  1125.0                  1125.0                     1.0
#
#    maximum_nights_avg_ntm calendar_updated  has_availability  availability_30  \
# 0                  1125.0              NaN              True                0
#
#    availability_60  availability_90  availability_365  \
# 0                0                0                 0
#
#        calendar_last_scraped  number_of_reviews  number_of_reviews_ltm  \
# 0  2022-06-03T00:00:00+00:00                316                    163
#
#    number_of_reviews_l30d               first_review  \
# 0                       5  2020-11-01T00:00:00+00:00
#
#                  last_review  review_scores_rating  review_scores_accuracy  \
# 0  2022-05-25T00:00:00+00:00                  4.66                    4.72
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.69                   4.87
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.86                    4.89                 4.61
#
#   license  instant_bookable  reviews_per_month access_date        country  \
# 0                     False              16.34  2022-06-03  united-states
#
#   state           city
# 0    ny  new-york-city

# %% [markdown]
# For good measure, let's also take a look at some recent reviews:

# %%
# %%sql listing_review_comments <<
#
# select review_date, comments
# from reviews r
# where listing_id = {listing_id}
# order by review_id desc
# limit 4
# Out:
# Returning data to local variable listing_review_comments

# %%
import textwrap

print('\n\n'.join(
    f'{r.review_date}:\n{textwrap.fill(r.comments)}'
    for r in listing_review_comments.itertuples()
))
# Out:
# 2022-05-25T00:00:00:
# Fantastic stay at this boutique hotel.  Fabulous location - so many
# great choices for dining, convenient to the 28th Street subway stop.
# The room was much larger than any others we've had in New York City -
# and we've stayed at quite a few hotels.  Perfectly fine for our girls'
# weekend! We were lucky with getting into our room early and stowing
# our bags the day of departure to maximize time for fun.  Hotel staff
# are friendly and were helpful with recommendations.  Would return and
# highly recommend this hotel!
#
# 2022-05-23T00:00:00:
# Great affordable upgraded downtown hotel with accommodating and
# friendly staff.  Lots of great restaurants nearby and the neighborhood
# is energized even into the later hours. Room had some normal street
# noise and city lights coming in. Bathroom was clean and updated. Bed
# was decently comfy. I would come back here, ok walk to lots of parks
# and attractions.
#
# 2022-05-22T00:00:00:
# Hammer Lage und freundliches Personal. Lediglich bei den Zimmern ist
# noch etwas Luft nach oben.
#
# 2022-05-22T00:00:00:
# this was the perfect location for us as it's central and we wanted to
# do a little of everything. the street outside is pedestrian only so
# it's really quiet at night. it's close to subways but if you like to
# walk you can walk almost anywhere. I  walked to a Broadway show,
# saint Patrick's cathedral and union square. the hotel is clean and all
# the staff are friendly and helpful. They made us feel welcome and
# safe. I like that the door is locked after 11 but there's someone
# waiting to let you in.

# %% [markdown]
# So in this case we have what appears to be a legitimate listing, but it's at a boutique hotel.  Far to the right in the `select *`, we see that `instant_bookable` is false.  Maybe you have to initiate the booking process before the price is revealed.

# %% [markdown]
# Anyway, we can add another condition `price > 0` to find some more plausible, but still cheap, prices:

# %%
# %%sql
#
# select
#     listing_id,
#     price,
#     accommodates,
#     minimum_nights,
#     neighbourhood_cleansed,
#     city,
#     state,
#     country
# from listings
# where
#     city = 'new-york-city'
#     and accommodates >= 4
#     and minimum_nights <= 2
#     and price > 0
# order by
#     price
# limit 5
# Out:
#    listing_id  price  accommodates  minimum_nights neighbourhood_cleansed  \
# 0    28607153   35.0             4               1        Jackson Heights
# 1    45565991   40.0             4               1          East Flatbush
# 2    51184699   40.0             4               1                 Inwood
# 3    49535021   42.0             4               1          East Elmhurst
# 4    36082249   45.0             4               1           Borough Park
#
#             city state        country
# 0  new-york-city    ny  united-states
# 1  new-york-city    ny  united-states
# 2  new-york-city    ny  united-states
# 3  new-york-city    ny  united-states
# 4  new-york-city    ny  united-states

# %% [markdown]
# ## Basic Aggregates

# %% [markdown]
# Sometimes filtering with `where` and sorting with `order by` is exactly what is needed in order to learn about data in context at the extremes.  But sometimes you just want to know what the extreme values are.
#
# This brings us to _aggregation_ and _aggregates_.  An aggregate, or aggregate function, is a calculation that operates on multiple values and returns a scalar value.  Aggregation is the process of preparing to compute, and ultimately computing, one or more aggregate functions.

# %% [markdown]
# ### `min()` and `max()`

# %% [markdown]
# Above we were interested in low prices.  We can find the lowest price with `min()`:

# %%
# %%sql
#
# select
#     min(price)
# from listings
# where
#     city = 'new-york-city'
#     and accommodates >= 4
#     and minimum_nights <= 2
#     and price > 0
# Out:
#    MIN("listings"."price")
# 0                     35.0

# %% [markdown]
# Conversely, using `max()` we can look for the most expensive room that only accommodates a single guest:

# %%
# %%sql
#
# select
#     max(price)
# from listings
# where
#     city = 'new-york-city'
#     and accommodates = 1
# Out:
#    MAX("listings"."price")
# 0                  10000.0

# %% [markdown]
# ### `count()`

# %% [markdown]
# One of the most useful aggregates is `count()`:

# %%
# %%sql
#
# select
#     count(1)
# from listings
# where city = 'new-york-city'
# Out:
#    COUNT(1)
# 0     37410

# %% [markdown]
# Note that `count()` counts non-null elements, **not** the number of rows!  For example:

# %%
# %%sql
#
# select
#     count(1),
#     count(beds),
#     count(bedrooms)
# from listings
# where city = 'new-york-city'
#     and accommodates >= 4
# Out:
#    COUNT(1)  COUNT("listings"."beds")  COUNT("listings"."bedrooms")
# 0     11026                     10914                         10474

# %% [markdown]
# Above, `count(beds)` differs from `count(bedrooms)` because "bedrooms" has more nulls than "beds".
#
# Note that `count(1)` is somewhat idiomatic, but any non-null literal will have the same effect, which is to simply count rows:

# %%
# %%sql
#
# select
#     count(1),
#     count(2),
#     count('unnecessary input here')
# from listings
# where city = 'new-york-city'
#     and accommodates >= 4
# Out:
#    COUNT(1)  COUNT(2)  COUNT('unnecessary input here')
# 0     11026     11026                            11026

# %% [markdown]
# ### `sum()` and `avg()`

# %% [markdown]
# Two more extremely useful aggregates are `sum()` and `avg()`:

# %%
# %%sql
#
# select
#     count(1),
#     sum(beds),
#     avg(beds)
# from listings
# where city = 'new-york-city'
#     and accommodates >= 4
# Out:
#    COUNT(1)  SUM("listings"."beds")  AVG("listings"."beds")
# 0     11026                 29610.0                2.713029

# %% [markdown]
# :::{.callout-note}
#
# Yes, in SQL `avg` is the way we spell "mean" or "average" – don't worry, you get used to it.
#
# :::

# %% [markdown]
# ## Aliasing

# %% [markdown]
# Aggregate result default column names are implementation-dependent.  We saw above that dask-sql assigns default names that reflect the expression being evaluated – for example, `avg(beds)` $\Rightarrow$ `AVG("listings"."beds")`.
#
# This default is ugly enough to motivate an alternative, but also explicit enough to give us a hint about SQL's column naming syntax.
#
# In most (all?) implementations, single quotes are used for strings while double quotes are used for schema/table/column names.  The above query could be written as:

# %%
# %%sql
#
# select
#     count(1),
#     sum("listings"."beds"),
#     avg("listings"."beds")
# from "listings"
# where "city" = 'new-york-city'
#     and "accommodates" >= 4
# Out:
#    COUNT(1)  SUM("listings"."beds")  AVG("listings"."beds")
# 0     11026                 29610.0                2.713029

# %% [markdown]
# Aliases are specified using either of the following syntaxes:
#
# * `<name> <alias>`
# * `<name> AS <alias>`
#
# For well-behaved names (identifiers that are not reserved words) the double-quotes are optional.  The `AS` is also optional.  So the most concise way to name our columns would be:

# %%
# %%sql
#
# select
#     count(1) num_listings,
#     sum(beds) total_beds,
#     avg(beds) mean_beds
# from listings
# where city = 'new-york-city'
#     and accommodates >= 4
# Out:
#    num_listings  total_beds  mean_beds
# 0         11026     29610.0   2.713029

# %% [markdown]
# Here's an example gratuitously inconsistent style that shows some of the various valid syntactic combinations:

# %%
# %%sql
#
# select
#     count(listing_id) as "num_listings",
#     sum(beds) as total_beds,
#     avg(l.beds) as "mean_beds"
# from listings l
# where city = 'new-york-city'
#     and accommodates >= 4
# Out:
#    num_listings  total_beds  mean_beds
# 0         11026     29610.0   2.713029

# %% [markdown]
# ## Teaser: aggregates with variable filters

# %% [markdown]
# Above we found some "number of beds" aggregates for New York City.  In this environment, embedded in JupyterLab, we can run similar calculations for all cities in the dataset:

# %%
cities = %sql select distinct city from listings
cities = cities.city.values
cities
# Out:
# array(['new-york-city', 'amsterdam', 'paris'], dtype=object)

# %%
for city in cities:
    x = %sql select '{city}' city, avg(beds) mean_beds from listings where city = '{city}' and accommodates >= 4
    display(x)
# Out:
#             city  mean_beds
# 0  new-york-city   2.713029
#         city  mean_beds
# 0  amsterdam   3.152174
#     city  mean_beds
# 0  paris   2.664234

# %% [markdown]
# Here we've introduced some new JupyterLab-specific SQL magic syntax: `%sql` with a single `%` can be followed by a single-line SQL query as an expression which can be assigned into a variable.
#
# More importantly, we've performed our first analysis consisting of an aggregate computed on some numerical column, for each possible value of some other categorical column.  In the next chapter we'll explore SQL's dedicated syntax for this type of analysis.

# %% [markdown]
# ## Exercises

# %% [markdown]
# **TODO.**
